# %%
import pandas as pd
import numpy as np
import os, sys
import plotly.express as px
import plotly.figure_factory as 
import matplotlib.pyplot as plt

# %%
"""
Day 1-1
"""

# %%
from scipy.stats import f_oneway, kruskal

# %%
day_1_1 = pd.read_csv("/Users/aseem/Downloads/Survey Compilation - Day1-1.csv")
day_2_1 = pd.read_csv("/Users/aseem/Downloads/Survey Compilation - Day2-1.csv")

# %%
day_1_1.describe()
# Out:
#        Agreement
# count  63.000000
# mean    4.195238
# std     1.112746
# min     1.000000
# 25%     3.650000
# 50%     5.000000
# 75%     5.000000
# max     5.000000

# %%
fig_hist = ff.create_distplot([day_1_1[day_1_1['Gender']=='M']['Agreement']], group_labels=['Male'])
fig_f  = ff.create_distplot([day_1_1[day_1_1['Gender']=='F']['Agreement']], group_labels=['Female'])
fig_hist.show()
fig_f.show()
# Out:
# <div>                            <div id="60c6873a-3398-44ee-8225-083d1ad7d234" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60c6873a-3398-44ee-8225-083d1ad7d234")) {                    Plotly.newPlot(                        "60c6873a-3398-44ee-8225-083d1ad7d234",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"Male","marker":{"color":"rgb(31, 119, 180)"},"name":"Male","opacity":0.7,"x":[4.0,4.0,2.5,5.0,5.0,5.0,5.0,4.8,5.0,3.0,2.2,5.0,5.0,4.8,4.0,3.8,2.0,5.0,5.0,4.0,2.7,5.0,5.0,4.2,5.0,5.0,5.0,5.0,3.0,5.0,5.0,1.0,3.2,5.0,5.0,5.0,5.0,4.0,5.0,2.8,5.0,1.0,3.0,3.0,5.0,5.0,4.8,5.0],"xaxis":"x","xbins":{"end":5.0,"size":1.0,"start":1.0},"yaxis":"y","type":"histogram"},{"legendgroup":"Male","marker":{"color":"rg
# ...

# %%
fig = px.histogram(day_2_1, x="Agreement", color="Gender",
                   marginal="box", # or violin, rug
                   hover_data=day_2_1.columns)
fig.show()
# Out:
# <div>                            <div id="fa329a89-dcc5-4a32-b7c4-cfde88952ce7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa329a89-dcc5-4a32-b7c4-cfde88952ce7")) {                    Plotly.newPlot(                        "fa329a89-dcc5-4a32-b7c4-cfde88952ce7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Gender=M<br>Agreement=%{x}<br>count=%{y}<extra></extra>","legendgroup":"M","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"x":[1.8,3.8,3.0,3.2,4.8,3.0,4.0,5.0,1.0,3.0,4.3,5.0,5.0,2.0,4.0,5.0,3.0,5.0,5.0,5.0,4.0,3.0,2.0,1.0,5.0,5.0,4.0,5.0,5.0,3.0,4.0,2.0,5.0,1.0,4.0,5.0,5.0,4.8,5.0,4.0,5.0,5.0,5.0,5.0,4.8,4.8,5.0,4.8,4.8,3.6,4.4,3.0,5.0,5
# ...

# %%
fig = px.histogram(day_2_1, x="Agreement", color="Gender",
                   marginal="box", # or violin, rug
                   hover_data=day_2_1.columns)
fig.show()
# Out:
# <div>                            <div id="a758db40-0166-4e2f-8403-df4c809bb5c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a758db40-0166-4e2f-8403-df4c809bb5c3")) {                    Plotly.newPlot(                        "a758db40-0166-4e2f-8403-df4c809bb5c3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Gender=M<br>Agreement=%{x}<br>count=%{y}<extra></extra>","legendgroup":"M","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"x":[1.8,3.8,3.0,3.2,4.8,3.0,4.0,5.0,1.0,3.0,4.3,5.0,5.0,2.0,4.0,5.0,3.0,5.0,5.0,5.0,4.0,3.0,2.0,1.0,5.0,5.0,4.0,5.0,5.0,3.0,4.0,2.0,5.0,1.0,4.0,5.0,5.0,4.8,5.0,4.0,5.0,5.0,5.0,5.0,4.8,4.8,5.0,4.8,4.8,3.6,4.4,3.0,5.0,5
# ...

# %%
fig_pie = px.pie(day_2_1, names='Gender')

# %%
fig_pie.show()
# Out:
# <div>                            <div id="8a641b0a-a7b3-4fb6-90c8-93ca5da9ff39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a641b0a-a7b3-4fb6-90c8-93ca5da9ff39")) {                    Plotly.newPlot(                        "8a641b0a-a7b3-4fb6-90c8-93ca5da9ff39",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Gender=%{label}<extra></extra>","labels":["M","M","M","M","M","M","F","M","M","F","M","M","M","M","M","F","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","F","F","M","M","M","M","M","M","M","F","M","M","F","M","M","M","M","F","M","F","F","M","F","M","M","M","M","F","F","M","F","M","F","M","M","M","M","M","M","M","M","F","M","M","M","M","M","F","M","F","M","M","M","M","M","F","F","M","M"]
# ...

# %%
import random

# %%
views = [random.randint(350,372) for _ in range(6)]
views
# Out:
# [363, 357, 355, 352, 359, 358]

# %%
views = [372, 370, 368, 383, 381, 380]

# %%
interactions = [59,49,48,90,88,92]

# %%
interact_data = {
    "views" : views,
    "responses" : interactions
 }

# %%
df = pd.DataFrame(interact_data)

# %%
# Out:
#    views  responses
# 0    372         59
# 1    370         49
# 2    368         48
# 3    383         90
# 4    381         88
# 5    380         92

# %%
line_fig = px.line(df)

# %%
line_fig.show()
# Out:
# <div>                            <div id="cd2ff77b-b909-43bc-8e75-13435b02ff8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd2ff77b-b909-43bc-8e75-13435b02ff8b")) {                    Plotly.newPlot(                        "cd2ff77b-b909-43bc-8e75-13435b02ff8b",                        [{"hovertemplate":"variable=views<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"views","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"views","orientation":"v","showlegend":true,"x":[0,1,2,3,4,5],"xaxis":"x","y":[372,370,368,383,381,380],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=responses<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"responses","line":{"color":"#EF553B","dash":"
# ...

# %% [markdown]
# ### Day 1 Combined ###

# %%
day_1 = pd.read_csv('/Users/aseem/Downloads/Survey Compilation - Day-1-combined.csv')
day_2 = pd.read_csv('/Users/aseem/Downloads/Survey Compilation - Day-2-combined.csv')
day_3 = pd.read_csv('/Users/aseem/Downloads/Survey Compilation - Day-3-combined.csv')

# %%
# standard devs of populations 
day_1['Agreement'].mean(), day_2['Agreement'].mean(), day_3['Agreement'].mean()
# Out:
# (4.205521472392638, 4.024727272727272, 3.9752380952380952)

# %%
fig = ff.create_distplot([day_1['Agreement'],day_2['Agreement']], ['poly_epsilon=1','poly_epsilon=20'])

# %%
fig.show()
# Out:
# <div>                            <div id="6eaf1755-80a5-4ae6-9668-54544575c506" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6eaf1755-80a5-4ae6-9668-54544575c506")) {                    Plotly.newPlot(                        "6eaf1755-80a5-4ae6-9668-54544575c506",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"poly_epsilon=1","marker":{"color":"rgb(31, 119, 180)"},"name":"poly_epsilon=1","opacity":0.7,"x":[4.0,4.0,5.0,2.5,5.0,5.0,5.0,5.0,5.0,4.8,5.0,5.0,3.0,2.2,5.0,5.0,4.8,4.0,3.8,2.0,5.0,5.0,4.0,2.7,5.0,5.0,5.0,4.2,3.5,2.5,5.0,5.0,4.0,5.0,5.0,5.0,5.0,3.0,5.0,2.7,5.0,1.0,3.2,2.0,5.0,5.0,4.2,5.0,5.0,4.0,5.0,2.8,5.0,3.8,1.0,4.8,3.0,3.0,5.0,5.0,5.0,4.8,5.0,4.0,5.0,5.0,5.0,5.0,4.8,4.3,4.8,3.8,3.7,3.7,4.3,4.0
# ...

# %%
day_1.describe()
# Out:
#         Agreement
# count  163.000000
# mean     4.205521
# std      1.027177
# min      1.000000
# 25%      3.800000
# 50%      4.800000
# 75%      5.000000
# max      5.000000

# %%
fig_pie = px.pie(day_1, names='Gender')
fig_pie.show()
# Out:
# <div>                            <div id="9482cf24-7bda-455f-aacb-019dedc72531" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9482cf24-7bda-455f-aacb-019dedc72531")) {                    Plotly.newPlot(                        "9482cf24-7bda-455f-aacb-019dedc72531",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Gender=%{label}<extra></extra>","labels":["M","M","F","M","M","M","M","M","F","M","F","M","M","M","M","M","M","M","M","M","M","M","M","M","M","F","M","M","F","F","F","M","F","F","M","M","M","M","M","F","M","M","M","F","M","M","F","M","M","M","M","M","M","F","M","F","M","M","M","F","M","M","M","M","M","F","M","M","M","M","M","M","M","M","M","M","M","F","M","M","F","F","M","F","F","M","M","M","M","F","M","M",
# ...

# %%
import math

# %%
log_10_1 = [math.log10(x) for x in day_1['Agreement']]

# %%
plt.hist(day_1["Agreement"])
# Out:
# (array([ 5.,  0.,  5.,  3.,  5., 15., 12., 18., 14., 86.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(day_2["Agreement"])
# Out:
# (array([ 12.,   1.,  17.,   3.,   4.,  42.,  14.,  41.,   5., 136.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(day_3['Agreement'])
# Out:
# (array([13.,  0.,  7.,  6.,  6., 25., 19., 32.,  6., 96.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(log_10_1)
# Out:
# (array([ 5.,  0.,  0.,  5.,  1.,  7., 15., 12., 32., 86.]),
#  array([0.30103   , 0.34874212, 0.39645425, 0.44416637, 0.4918785 ,
#         0.53959062, 0.58730275, 0.63501487, 0.682727  , 0.73043912,
#         0.77815125]),
#  <BarContainer object of 10 artists>)

# %%
kruskal(day_1['Agreement'], day_2['Agreement'], day_3['Agreement'])
# Out:
# KruskalResult(statistic=4.027502674733008, pvalue=0.13348697954899952)

# %%
combined_3 = pd.concat([day_1, day_2, day_3],axis=0)

# %%
combined_3['Agreement'].shape
# Out:
# (648,)

# %%
combined_3['Agreement'].describe()
# Out:
# count    648.000000
# mean       4.054167
# std        1.128518
# min        1.000000
# 25%        3.300000
# 50%        4.400000
# 75%        5.000000
# max        5.000000
# Name: Agreement, dtype: float64

# %%
plt.hist(combined_3['Agreement'])
plt.xlabel("Agreement Score")
plt.ylabel("Count")
plt.savefig('dist.png', transparent = True)
